# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashwat-143/Image-to-Pencil-Sketch-using-Python/blob/main/Image_to_Pencil_Sketch_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Image to Pencil Sketch using Python**

# %% [markdown]
# The project will use the Python programming language to convert an image into a pencil sketch. The following steps will be involved:
#
# 1. Import the necessary Python libraries, such as OpenCV and matplotlib.
# 2. Using matplotlib library for some visualizations.
# 3. Convert the image to grayscale using the cv2.cvtColor() function.
# 4. Apply a Gaussian blur to the grayscale image using the cv2.GaussianBlur() function.
# 5. Invert the blurred image using the cv2.bitwise_not() function.

# %% [markdown]
# **Import Libraries**

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
#  **Read Photo**

# %%
img=cv2.imread("/content/Shashwat Prasad Photo.jpeg")

# %% [markdown]
# **Show Image using OpenCV**

# %%
cv2_imshow(cv2.resize(img, (600, 600)))
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F9177A639D0>

# %% [markdown]
# **Display using Matplotlib**

# %%
plt.imshow(img)
plt.axis(False)
plt.show()

# %% [markdown]
# **Convert BGR to RGB**

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.axis(False)
plt.show()

# %% [markdown]
# **Convert Image to a Pencil Sketch**

# %% [markdown]
# Step-1: Convert to Grey Image

# %%
grey_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# Step-2: Invert Image

# %%
invert_img=cv2.bitwise_not(grey_img)

# %% [markdown]
# Step-3: Blur Image

# %%
blur_img=cv2.GaussianBlur(invert_img, (111,111),0)

# %% [markdown]
# Step-4: Invert Blurred Image

# %%
invblur_img=cv2.bitwise_not(blur_img)

# %% [markdown]
# Step-5: Sketch

# %%
sketch_img=cv2.divide(grey_img,invblur_img, scale=256.0)

# %% [markdown]
# Step-6: Save Sketch

# %%
cv2.imwrite('sketch.png', sketch_img)
# Out:
# True

# %% [markdown]
# Step-7: Display Sketch

# %%
cv2_imshow(cv2.resize(img, (600, 600)))
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F91779914E0>

# %% [markdown]
# **Original Image vs Sketch**

# %%
plt.figure(figsize=(14,8))
plt.subplot(1,2,1)
plt.title('Original image', size=18)
plt.imshow(RGB_img)
plt.axis('off')
plt.subplot(1,2,2)
plt.title('Sketch', size=18)
rgb_sketch=cv2.cvtColor(sketch_img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_sketch)
plt.axis('off')
plt.show()
